# %%
from load_data import  sim_arr

# %%
import numpy as np
from sklearn.model_selection import train_test_split


# Split the data into train, test and validation sets
train_set, test_set = train_test_split(sim_arr, test_size=0.2, random_state=42)
train_set, valid_set = train_test_split(
    train_set, test_size=0.2, random_state=42)

print("Train set size: ", len(train_set),
      " Test set size: ", len(test_set),
      " Validation set size: ", len(valid_set))
# Out:
# Train set size:  1926  Test set size:  602  Validation set size:  482

# %%
# check gpu
import tensorflow as tf
print("Num GPUs Available: ", len(
    tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import optuna

from tensorflow.keras.layers import InputLayer, Conv2D, MaxPool2D, Conv2DTranspose
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MeanSquaredError

# get input shape from the data
input_shape = train_set.shape[1:]
output_shape = (1, 1, 12)


def create_model(trial):
    # Hyperparameters to optimize
    num_layers = trial.suggest_int('num_layers', 1, 4)

    filters = [trial.suggest_categorical(f'filters_{i}', [3, 6, 9, 12])
               for i in range(num_layers - 1)]
    filters.append(12)

    activation = [trial.suggest_categorical(
        f'activation_{i}', ['relu', 'selu', 'tanh', 'sigmoid']) for i in range(num_layers)]
    
    initializer = [trial.suggest_categorical(
        f'initializer_{i}', ['lecun_normal', 'he_normal', 'he_uniform', 'glorot_normal', 'glorot_uniform']) for i in range(num_layers)]

    kernel_sizes = [trial.suggest_int(
        f'kernel_size{i}', 2, 8) for i in range(num_layers)]

    poolsize = [[16],
                [4, 4],
                [2, 2, 4],
                [2, 2, 2, 2]]

    # Encoder
    encoder = Sequential(name='encoder')
    encoder.add(InputLayer(input_shape=input_shape))
    for i in range(num_layers):
        encoder.add(MaxPool2D(poolsize[num_layers - 1][i]))
        encoder.add(Conv2D(
            filters[i],
            kernel_sizes[i],
            strides=1,
            activation=activation[i],
            padding='same',
            kernel_initializer=initializer[i]
        ))
    encoder.add(MaxPool2D(5))

    # Decoder
    decoder = Sequential(name='decoder')
    decoder.add(InputLayer(input_shape=encoder.output_shape[1:]))
    for i in range(num_layers - 1, -1, -1):
        decoder.add(Conv2DTranspose(
            filters[i],
            kernel_sizes[i],
            strides=poolsize[num_layers - 1][i],
            activation=activation[i],
            padding='same',
            kernel_initializer=initializer[i]
        ))
    decoder.add(Conv2DTranspose(
        input_shape[-1],
        kernel_sizes[0],
        strides=5,
        activation=activation[0],
        padding='same',
        kernel_initializer=initializer[0]
    ))

    # Compile the model
    auto_encoder = Sequential([encoder, decoder], name="autoencoder")
    auto_encoder.compile(optimizer='adam', loss="MSE")

    return auto_encoder


def objective(trial):
    # Clear clutter from previous sessions
    tf.keras.backend.clear_session()

    # Create model
    model = create_model(trial)

    # Train the model
    history = model.fit(train_set, train_set, epochs=10, batch_size=32,
                        validation_data=(valid_set, valid_set), verbose=0)

    return history.history['val_loss'][-1]


# Perform hyperparameter optimization
study = optuna.create_study(direction='minimize',
                            pruner=optuna.pruners.HyperbandPruner(),
                            study_name='autoencoder_1',
                            storage='sqlite:///test.db',
                            load_if_exists=True)
study.optimize(objective, n_trials=100)


# Get the best hyperparameters
best_params = study.best_params
print("Best hyperparameters:", best_params)
# Out:
# [I 2024-03-20 10:30:30,130] Using an existing study with name 'autoencoder_1' instead of creating a new one.
# [I 2024-03-20 10:30:40,951] Trial 3 finished with value: 0.1679535210132599 and parameters: {'num_layers': 4, 'filters_0': 12, 'filters_1': 6, 'filters_2': 3, 'activation_0': 'sigmoid', 'activation_1': 'sigmoid', 'activation_2': 'selu', 'activation_3': 'sigmoid', 'initializer_0': 'he_normal', 'initializer_1': 'he_normal', 'initializer_2': 'glorot_uniform', 'initializer_3': 'lecun_normal', 'kernel_size0': 6, 'kernel_size1': 2, 'kernel_size2': 8, 'kernel_size3': 5}. Best is trial 3 with value: 0.1679535210132599.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710927045.221335    4399 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:30:48,339] Trial 4 finished with value: 0.17055988311767578 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'tanh', 'activation_1': 'relu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_normal', 'kernel_size0': 2, 'kernel_size1': 5}. Best is trial 3 with value: 0.1679535210132599.
# [I 2024-03-20 10:30:58,195] Trial 5 finished with value: 0.16840355098247528 and parameters: {'num_layers': 4, 'filters_0': 6, 'filters_1': 9, 'filters_2': 3, 'activation_0': 'relu', 'activation_1': 'selu', 'activation_2': 'selu', 'activation_3': 'sigmoid', 'initializer_0': 'glorot_uniform', 'initializer_1': 'lecun_normal', 'initializer_2': 'glorot_uniform', 'initializer_3': 'he_normal', 'kernel_size0': 2, 'kernel_size1': 2, 'kernel_size2': 8, 'kernel_size3': 4}. Best is trial 3 with value: 0.1679535210132599.
# [I 2024-03-20 10:31:04,100] Trial 6 finished with value: 0.16953440010547638 and parameters: {'num_layers': 1, 'activation_0': 'sigmoid', 'initializer_0': 'he_uniform', 'kernel_size0': 6}. Best is trial 3 with value: 0.1679535210132599.
# [I 2024-03-20 10:31:10,884] Trial 7 finished with value: 0.17123554646968842 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'tanh', 'activation_1': 'relu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_normal', 'kernel_size0': 2, 'kernel_size1': 4}. Best is trial 3 with value: 0.1679535210132599.
# [I 2024-03-20 10:31:21,478] Trial 8 finished with value: 0.0843648910522461 and parameters: {'num_layers': 4, 'filters_0': 3, 'filters_1': 9, 'filters_2': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'activation_2': 'selu', 'activation_3': 'sigmoid', 'initializer_0': 'he_uniform', 'initializer_1': 'he_normal', 'initializer_2': 'glorot_uniform', 'initializer_3': 'he_normal', 'kernel_size0': 4, 'kernel_size1': 8, 'kernel_size2': 7, 'kernel_size3': 4}. Best is trial 8 with value: 0.0843648910522461.
# [I 2024-03-20 10:31:30,609] Trial 9 finished with value: 0.13679848611354828 and parameters: {'num_layers': 3, 'filters_0': 12, 'filters_1': 6, 'activation_0': 'relu', 'activation_1': 'tanh', 'activation_2': 'selu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'he_normal', 'initializer_2': 'glorot_normal', 'kernel_size0': 3, 'kernel_size1': 4, 'kernel_size2': 6}. Best is trial 8 with value: 0.0843648910522461.
# [I 2024-03-20 10:31:38,883] Trial 10 finished with value: 0.21643571555614471 and parameters: {'num_layers': 3, 'filters_0': 3, 'filters_1': 3, 'activation_0': 'sigmoid', 'activation_1': 'tanh', 'activation_2': 'relu', 'initializer_0': 'he_normal', 'initializer_1': 'glorot_uniform', 'initializer_2': 'glorot_normal', 'kernel_size0': 4, 'kernel_size1': 7, 'kernel_size2': 4}. Best is trial 8 with value: 0.0843648910522461.
# [I 2024-03-20 10:31:48,128] Trial 11 finished with value: 0.15249164402484894 and parameters: {'num_layers': 3, 'filters_0': 3, 'filters_1': 12, 'activation_0': 'tanh', 'activation_1': 'selu', 'activation_2': 'tanh', 'initializer_0': 'he_normal', 'initializer_1': 'he_uniform', 'initializer_2': 'he_normal', 'kernel_size0': 2, 'kernel_size1': 6, 'kernel_size2': 8}. Best is trial 8 with value: 0.0843648910522461.
# [I 2024-03-20 10:31:56,780] Trial 12 finished with value: 0.17048867046833038 and parameters: {'num_layers': 3, 'filters_0': 9, 'filters_1': 9, 'activation_0': 'sigmoid', 'activation_1': 'sigmoid', 'activation_2': 'tanh', 'initializer_0': 'he_normal', 'initializer_1': 'lecun_normal', 'initializer_2': 'lecun_normal', 'kernel_size0': 6, 'kernel_size1': 4, 'kernel_size2': 4}. Best is trial 8 with value: 0.0843648910522461.
# [I 2024-03-20 10:32:07,649] Trial 13 finished with value: 0.016387134790420532 and parameters: {'num_layers': 4, 'filters_0': 3, 'filters_1': 9, 'filters_2': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'activation_2': 'sigmoid', 'activation_3': 'tanh', 'initializer_0': 'he_uniform', 'initializer_1': 'he_normal', 'initializer_2': 'he_uniform', 'initializer_3': 'he_normal', 'kernel_size0': 8, 'kernel_size1': 8, 'kernel_size2': 2, 'kernel_size3': 8}. Best is trial 13 with value: 0.016387134790420532.
# [I 2024-03-20 10:32:15,868] Trial 14 finished with value: 0.01848703622817993 and parameters: {'num_layers': 4, 'filters_0': 3, 'filters_1': 9, 'filters_2': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'activation_2': 'sigmoid', 'activation_3': 'tanh', 'initializer_0': 'he_uniform', 'initializer_1': 'he_normal', 'initializer_2': 'he_uniform', 'initializer_3': 'he_normal', 'kernel_size0': 8, 'kernel_size1': 8, 'kernel_size2': 2, 'kernel_size3': 8}. Best is trial 13 with value: 0.016387134790420532.
# [I 2024-03-20 10:32:24,208] Trial 15 finished with value: 0.018632078543305397 and parameters: {'num_layers': 4, 'filters_0': 3, 'filters_1': 9, 'filters_2': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'activation_2': 'sigmoid', 'activation_3': 'tanh', 'initializer_0': 'he_uniform', 'initializer_1': 'he_normal', 'initializer_2': 'he_uniform', 'initializer_3': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 8, 'kernel_size2': 2, 'kernel_size3': 8}. Best is trial 13 with value: 0.016387134790420532.
# [I 2024-03-20 10:32:34,682] Trial 16 finished with value: 0.020051714032888412 and parameters: {'num_layers': 4, 'filters_0': 3, 'filters_1': 9, 'filters_2': 12, 'activation_0': 'selu', 'activation_1': 'relu', 'activation_2': 'sigmoid', 'activation_3': 'tanh', 'initializer_0': 'he_uniform', 'initializer_1': 'he_normal', 'initializer_2': 'he_uniform', 'initializer_3': 'he_uniform', 'kernel_size0': 8, 'kernel_size1': 7, 'kernel_size2': 2, 'kernel_size3': 8}. Best is trial 13 with value: 0.016387134790420532.
# I0000 00:00:1710927157.498194    4400 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:32:40,517] Trial 17 finished with value: 0.1379079520702362 and parameters: {'num_layers': 1, 'activation_0': 'selu', 'initializer_0': 'he_uniform', 'kernel_size0': 7}. Best is trial 13 with value: 0.016387134790420532.
# [I 2024-03-20 10:32:51,799] Trial 18 finished with value: 0.017297836020588875 and parameters: {'num_layers': 4, 'filters_0': 9, 'filters_1': 12, 'filters_2': 6, 'activation_0': 'selu', 'activation_1': 'relu', 'activation_2': 'sigmoid', 'activation_3': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'initializer_2': 'he_uniform', 'initializer_3': 'he_normal', 'kernel_size0': 7, 'kernel_size1': 7, 'kernel_size2': 3, 'kernel_size3': 7}. Best is trial 13 with value: 0.016387134790420532.
# [I 2024-03-20 10:32:59,241] Trial 19 finished with value: 0.009934450499713421 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 19 with value: 0.009934450499713421.
# [I 2024-03-20 10:33:05,351] Trial 20 finished with value: 0.012531014159321785 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 19 with value: 0.009934450499713421.
# [I 2024-03-20 10:33:13,209] Trial 21 finished with value: 0.012566277757287025 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 5, 'kernel_size1': 6}. Best is trial 19 with value: 0.009934450499713421.
# [I 2024-03-20 10:33:21,064] Trial 22 finished with value: 0.09000391513109207 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'relu', 'activation_1': 'sigmoid', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 19 with value: 0.009934450499713421.
# I0000 00:00:1710927204.045347    4398 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:33:27,008] Trial 23 finished with value: 0.15780401229858398 and parameters: {'num_layers': 1, 'activation_0': 'selu', 'initializer_0': 'lecun_normal', 'kernel_size0': 5}. Best is trial 19 with value: 0.009934450499713421.
# [I 2024-03-20 10:33:33,125] Trial 24 finished with value: 0.011701086536049843 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 5, 'kernel_size1': 6}. Best is trial 19 with value: 0.009934450499713421.
# [I 2024-03-20 10:33:40,466] Trial 25 finished with value: 0.00918857753276825 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 6, 'kernel_size1': 6}. Best is trial 25 with value: 0.00918857753276825.
# [I 2024-03-20 10:33:46,704] Trial 26 finished with value: 0.009003493934869766 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 6, 'kernel_size1': 6}. Best is trial 26 with value: 0.009003493934869766.
# [I 2024-03-20 10:33:52,351] Trial 27 finished with value: 0.14829783141613007 and parameters: {'num_layers': 1, 'activation_0': 'selu', 'initializer_0': 'glorot_normal', 'kernel_size0': 6}. Best is trial 26 with value: 0.009003493934869766.
# [I 2024-03-20 10:34:00,083] Trial 28 finished with value: 0.009623724967241287 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 6, 'kernel_size1': 5}. Best is trial 26 with value: 0.009003493934869766.
# I0000 00:00:1710927244.008393    4399 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:34:07,137] Trial 29 finished with value: 0.07554227113723755 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 4, 'kernel_size1': 5}. Best is trial 26 with value: 0.009003493934869766.
# [I 2024-03-20 10:34:15,818] Trial 30 finished with value: 0.08215179294347763 and parameters: {'num_layers': 3, 'filters_0': 9, 'filters_1': 3, 'activation_0': 'relu', 'activation_1': 'selu', 'activation_2': 'relu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'initializer_2': 'he_normal', 'kernel_size0': 6, 'kernel_size1': 3, 'kernel_size2': 6}. Best is trial 26 with value: 0.009003493934869766.
# I0000 00:00:1710927258.492950    4398 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:34:21,601] Trial 31 finished with value: 0.15792030096054077 and parameters: {'num_layers': 1, 'activation_0': 'tanh', 'initializer_0': 'lecun_normal', 'kernel_size0': 5}. Best is trial 26 with value: 0.009003493934869766.
# [I 2024-03-20 10:34:29,779] Trial 32 finished with value: 0.15501363575458527 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'sigmoid', 'activation_1': 'selu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'glorot_uniform', 'kernel_size0': 6, 'kernel_size1': 5}. Best is trial 26 with value: 0.009003493934869766.
# [I 2024-03-20 10:34:38,567] Trial 33 finished with value: 0.015087061561644077 and parameters: {'num_layers': 3, 'filters_0': 12, 'filters_1': 12, 'activation_0': 'selu', 'activation_1': 'selu', 'activation_2': 'relu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'initializer_2': 'lecun_normal', 'kernel_size0': 6, 'kernel_size1': 7, 'kernel_size2': 5}. Best is trial 26 with value: 0.009003493934869766.
# [I 2024-03-20 10:34:45,600] Trial 34 finished with value: 0.008360710926353931 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 34 with value: 0.008360710926353931.
# I0000 00:00:1710927289.958046    4398 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:34:53,381] Trial 35 finished with value: 0.007561966776847839 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 35 with value: 0.007561966776847839.
# [I 2024-03-20 10:34:59,552] Trial 36 finished with value: 0.00742270378395915 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:35:06,445] Trial 37 finished with value: 0.008067206479609013 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# I0000 00:00:1710927309.149473    4399 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:35:12,105] Trial 38 finished with value: 0.1388942003250122 and parameters: {'num_layers': 1, 'activation_0': 'tanh', 'initializer_0': 'lecun_normal', 'kernel_size0': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:35:19,193] Trial 39 finished with value: 0.05941597372293472 and parameters: {'num_layers': 2, 'filters_0': 12, 'activation_0': 'relu', 'activation_1': 'selu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'glorot_normal', 'kernel_size0': 8, 'kernel_size1': 4}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:35:25,950] Trial 40 finished with value: 0.007818692363798618 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:35:31,318] Trial 41 finished with value: 0.16715776920318604 and parameters: {'num_layers': 1, 'activation_0': 'sigmoid', 'initializer_0': 'glorot_normal', 'kernel_size0': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:35:41,528] Trial 42 finished with value: 0.014446105808019638 and parameters: {'num_layers': 3, 'filters_0': 9, 'filters_1': 6, 'activation_0': 'tanh', 'activation_1': 'tanh', 'activation_2': 'tanh', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'initializer_2': 'lecun_normal', 'kernel_size0': 8, 'kernel_size1': 5, 'kernel_size2': 5}. Best is trial 36 with value: 0.00742270378395915.
# I0000 00:00:1710927347.196174    4399 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion', 8 bytes spill stores, 8 bytes spill loads
#
# [I 2024-03-20 10:35:50,631] Trial 43 finished with value: 0.05375313758850098 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'selu', 'activation_1': 'sigmoid', 'initializer_0': 'he_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 3}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:35:57,480] Trial 44 finished with value: 0.008082746528089046 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:04,311] Trial 45 finished with value: 0.007920649833977222 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:11,803] Trial 46 finished with value: 0.0081243384629488 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 8, 'kernel_size1': 4}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:18,765] Trial 47 finished with value: 0.007592569105327129 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'lecun_normal', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:27,419] Trial 48 finished with value: 0.1675746589899063 and parameters: {'num_layers': 3, 'filters_0': 9, 'filters_1': 3, 'activation_0': 'sigmoid', 'activation_1': 'selu', 'activation_2': 'relu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'lecun_normal', 'initializer_2': 'glorot_normal', 'kernel_size0': 8, 'kernel_size1': 4, 'kernel_size2': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:33,997] Trial 49 finished with value: 0.14205685257911682 and parameters: {'num_layers': 2, 'filters_0': 12, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'lecun_normal', 'kernel_size0': 3, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:42,464] Trial 50 finished with value: 0.0687500610947609 and parameters: {'num_layers': 3, 'filters_0': 9, 'filters_1': 3, 'activation_0': 'relu', 'activation_1': 'tanh', 'activation_2': 'tanh', 'initializer_0': 'glorot_uniform', 'initializer_1': 'lecun_normal', 'initializer_2': 'he_normal', 'kernel_size0': 7, 'kernel_size1': 3, 'kernel_size2': 4}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:50,290] Trial 51 finished with value: 0.008701297454535961 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'he_normal', 'initializer_1': 'glorot_normal', 'kernel_size0': 8, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:36:55,922] Trial 52 finished with value: 0.13783177733421326 and parameters: {'num_layers': 1, 'activation_0': 'selu', 'initializer_0': 'glorot_uniform', 'kernel_size0': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:02,979] Trial 53 finished with value: 0.011026101186871529 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_uniform', 'initializer_1': 'he_uniform', 'kernel_size0': 6, 'kernel_size1': 4}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:09,979] Trial 54 finished with value: 0.007970204576849937 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'lecun_normal', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:16,928] Trial 55 finished with value: 0.008190144784748554 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'lecun_normal', 'kernel_size0': 7, 'kernel_size1': 4}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:24,010] Trial 56 finished with value: 0.008533109910786152 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'lecun_normal', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:32,665] Trial 57 finished with value: 0.030014948919415474 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'sigmoid', 'initializer_0': 'lecun_normal', 'initializer_1': 'lecun_normal', 'kernel_size0': 8, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:39,862] Trial 58 finished with value: 0.008214340545237064 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'he_uniform', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:47,441] Trial 59 finished with value: 0.009335007518529892 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'tanh', 'initializer_0': 'he_normal', 'initializer_1': 'lecun_normal', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:37:54,693] Trial 60 finished with value: 0.009835653007030487 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 6, 'kernel_size1': 4}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:01,996] Trial 61 finished with value: 0.01176371704787016 and parameters: {'num_layers': 2, 'filters_0': 3, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'lecun_normal', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:11,314] Trial 62 finished with value: 0.1434239149093628 and parameters: {'num_layers': 3, 'filters_0': 12, 'filters_1': 12, 'activation_0': 'sigmoid', 'activation_1': 'selu', 'activation_2': 'relu', 'initializer_0': 'lecun_normal', 'initializer_1': 'glorot_normal', 'initializer_2': 'lecun_normal', 'kernel_size0': 8, 'kernel_size1': 7, 'kernel_size2': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:16,998] Trial 63 finished with value: 0.1485111266374588 and parameters: {'num_layers': 1, 'activation_0': 'selu', 'initializer_0': 'lecun_normal', 'kernel_size0': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:24,122] Trial 64 finished with value: 0.007802513428032398 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:31,301] Trial 65 finished with value: 0.007923496887087822 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:38,562] Trial 66 finished with value: 0.008055904880166054 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 5}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:44,955] Trial 67 finished with value: 0.007859214209020138 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:52,393] Trial 68 finished with value: 0.035894058644771576 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'sigmoid', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 6, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:38:59,318] Trial 69 finished with value: 0.06366127729415894 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'relu', 'activation_1': 'selu', 'initializer_0': 'he_uniform', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:06,876] Trial 70 finished with value: 0.007625805679708719 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:14,157] Trial 71 finished with value: 0.008050026372075081 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_normal', 'kernel_size0': 8, 'kernel_size1': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:21,791] Trial 72 finished with value: 0.016495177522301674 and parameters: {'num_layers': 2, 'filters_0': 3, 'activation_0': 'selu', 'activation_1': 'tanh', 'initializer_0': 'glorot_uniform', 'initializer_1': 'he_uniform', 'kernel_size0': 6, 'kernel_size1': 8}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:29,542] Trial 73 finished with value: 0.14248047769069672 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 3, 'kernel_size1': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:36,132] Trial 74 finished with value: 0.0077323163859546185 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:42,656] Trial 75 finished with value: 0.007537159137427807 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:49,283] Trial 76 finished with value: 0.007726103533059359 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:39:56,565] Trial 77 finished with value: 0.01230282336473465 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'relu', 'initializer_0': 'lecun_normal', 'initializer_1': 'he_uniform', 'kernel_size0': 7, 'kernel_size1': 7}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:40:03,056] Trial 78 finished with value: 0.007497716695070267 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'he_normal', 'kernel_size0': 7, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:40:10,400] Trial 79 finished with value: 0.010490956716239452 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 6, 'kernel_size1': 6}. Best is trial 36 with value: 0.00742270378395915.
# [I 2024-03-20 10:40:17,921] Trial 80 finished with value: 0.006786040961742401 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 80 with value: 0.006786040961742401.
# [I 2024-03-20 10:40:27,749] Trial 81 finished with value: 0.16733543574810028 and parameters: {'num_layers': 3, 'filters_0': 9, 'filters_1': 6, 'activation_0': 'sigmoid', 'activation_1': 'selu', 'activation_2': 'tanh', 'initializer_0': 'glorot_normal', 'initializer_1': 'he_normal', 'initializer_2': 'he_normal', 'kernel_size0': 8, 'kernel_size1': 7, 'kernel_size2': 3}. Best is trial 80 with value: 0.006786040961742401.
# [I 2024-03-20 10:40:33,021] Trial 82 finished with value: 0.157669797539711 and parameters: {'num_layers': 1, 'activation_0': 'selu', 'initializer_0': 'glorot_normal', 'kernel_size0': 5}. Best is trial 80 with value: 0.006786040961742401.
# [I 2024-03-20 10:40:40,346] Trial 83 finished with value: 0.07503409683704376 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'he_normal', 'kernel_size0': 4, 'kernel_size1': 6}. Best is trial 80 with value: 0.006786040961742401.
# [I 2024-03-20 10:40:46,967] Trial 84 finished with value: 0.006969469599425793 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 80 with value: 0.006786040961742401.
# [I 2024-03-20 10:40:53,532] Trial 85 finished with value: 0.006743640173226595 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 85 with value: 0.006743640173226595.
# [I 2024-03-20 10:41:00,028] Trial 86 finished with value: 0.006350200157612562 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:07,178] Trial 87 finished with value: 0.061337780207395554 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'relu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:14,840] Trial 88 finished with value: 0.008250853978097439 and parameters: {'num_layers': 2, 'filters_0': 12, 'activation_0': 'selu', 'activation_1': 'relu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:21,333] Trial 89 finished with value: 0.006760364398360252 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:28,882] Trial 90 finished with value: 0.03483150154352188 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'sigmoid', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:36,392] Trial 91 finished with value: 0.010375313460826874 and parameters: {'num_layers': 2, 'filters_0': 3, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:43,909] Trial 92 finished with value: 0.007524264045059681 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:51,337] Trial 93 finished with value: 0.011240669526159763 and parameters: {'num_layers': 2, 'filters_0': 6, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:41:58,493] Trial 94 finished with value: 0.00794482883065939 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:04,843] Trial 95 finished with value: 0.007963152602314949 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:11,504] Trial 96 finished with value: 0.007484385743737221 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:18,152] Trial 97 finished with value: 0.008252336643636227 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:24,785] Trial 98 finished with value: 0.007730282377451658 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:32,262] Trial 99 finished with value: 0.007875380106270313 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 7}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:39,962] Trial 100 finished with value: 0.010692136362195015 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'tanh', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:46,416] Trial 101 finished with value: 0.007392284460365772 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}. Best is trial 86 with value: 0.006350200157612562.
# [I 2024-03-20 10:42:53,025] Trial 102 finished with value: 0.008747046813368797 and parameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'tanh', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 7}. Best is trial 86 with value: 0.006350200157612562.
# Best hyperparameters: {'num_layers': 2, 'filters_0': 9, 'activation_0': 'selu', 'activation_1': 'selu', 'initializer_0': 'glorot_normal', 'initializer_1': 'glorot_uniform', 'kernel_size0': 8, 'kernel_size1': 6}

# %%
# Train the model with the best hyperparameters
auto_encoder = create_model(study.best_trial)
history = auto_encoder.fit(train_set, train_set, epochs=10, batch_size=32,
                           validation_data=(valid_set, valid_set))

auto_encoder.evaluate(test_set, test_set)
# Out:
# Epoch 1/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.2215 - val_loss: 0.0723
# Epoch 2/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0618 - val_loss: 0.0353
# Epoch 3/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0338 - val_loss: 0.0223
# Epoch 4/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0223 - val_loss: 0.0154
# Epoch 5/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0152 - val_loss: 0.0120
# Epoch 6/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - val_loss: 0.0101
# Epoch 7/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105 - val_loss: 0.0089
# Epoch 8/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 9/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - val_loss: 0.0074
# Epoch 10/10
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0069
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0078
# 0.007773946039378643

# %%
# summarize the encoder and decoder architecture
auto_encoder.get_layer('encoder').summary()
auto_encoder.get_layer('decoder').summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 20, 20, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 20, 20, 9)      │         1,737 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 5, 5, 9)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 5, 5, 12)       │         3,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 1, 1, 12)       │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,637 (22.02 KB)
#  Trainable params: 5,637 (22.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_transpose_3              │ (None, 4, 4, 12)       │         5,196 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 16, 16, 9)      │         6,921 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 80, 80, 3)      │         1,731 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,848 (54.09 KB)
#  Trainable params: 13,848 (54.09 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], "-o", label="loss")
plt.plot(history.history["val_loss"], "-o", label="validation loss")
plt.xlabel("epochs")
plt.ylabel("Mean Squared Error")
plt.legend()
plt.grid()
plt.show()

# %%
i = 25
in_sim = test_set[i: i + 1]
out_sim = auto_encoder(in_sim)
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].imshow(in_sim[0, ..., 2], vmin=-1, vmax=1, cmap="RdBu")
ax[1].imshow(out_sim[0, ..., 2], vmin=-1, vmax=1, cmap="RdBu")

# %%
from tensorflow.keras.layers import Flatten as Flatten

feature_extractor = Sequential(
    [
        auto_encoder.get_layer("encoder"),
        Flatten(),
    ]
)

feat_shape = auto_encoder.get_layer("encoder").output_shape[-1]

feature_arr = feature_extractor.predict(sim_arr, verbose=2)
# Out:
# 95/95 - 1s - 6ms/step

# %%
# Save the feature array
np.save("feature_arr.npy", feature_arr)
